# %%
a = pd.Series([15,20,12,8,20,5,10,10], name='Test Score', index = ["Ifeoma", "Emmanuel", "Taiwo","Chidinma", "Sukanmi","Loveline", "Ajuzie","Victoria"])

# %%
a
# Out:
# Ifeoma      15
# Emmanuel    20
# Taiwo       12
# Chidinma     8
# Sukanmi     20
# Loveline     5
# Ajuzie      10
# Victoria    10
# Name: Test Score, dtype: int64

# %%
a.plot(kind="pie",figsize=(10,8))
# Out:
# <AxesSubplot:ylabel='Test Score'>

# %%
a.plot(kind="pie",figsize=(10,8), counterclock=False,colors=["pink","blue","green","magenta","white","red","yellow","cyan"])
# Out:
# <AxesSubplot:ylabel='Test Score'>

# %%
a.plot(kind="pie",figsize=(10,8), shadow= True,colors=["pink","blue","green","magenta","white","red","yellow","cyan"])
# Out:
# <AxesSubplot:ylabel='Test Score'>

# %%
a.plot(kind="pie",figsize=(10,8), shadow= True, startangle=90, counterclock=False,colors=["pink","blue","green","magenta","white","red","yellow","cyan"])
# Out:
# <AxesSubplot:ylabel='Test Score'>

# %%
a.plot(kind="pie",figsize=(10,8), shadow= True, startangle=90, counterclock=False,colors=["pink","blue","green","magenta","white","red","yellow","cyan"])
# Out:
# <AxesSubplot:ylabel='Test Score'>

# %%
a.plot(kind="pie",figsize=(10,8), shadow= True, startangle=90, counterclock=False, label="Orange Sharing",colors=["pink","blue","green","magenta","white","red","yellow","cyan"])
# Out:
# <AxesSubplot:ylabel='Orange Sharing'>
